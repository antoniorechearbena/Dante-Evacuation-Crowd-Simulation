# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

upper = np.percentile(grid.values, 99)
grid_clipped = np.clip(grid, 0, upper)

df = pd.read_csv("pressure-heatmap.csv")
grid = df.pivot(index="y", columns="x", values="pressure")
plt.figure(figsize=(6, 5))
plt.imshow(grid_clipped, origin="lower")
plt.colorbar(label="Pressure (clipped at 99th percentile)")
plt.xlabel("pxcor")
plt.ylabel("pycor")
plt.title("Pressure Heatmap")
plt.tight_layout()
plt.savefig("pressure-heatmap.png", dpi=300)
plt.show()
